# %%
import os
import requests
import json
from dotenv import load_dotenv

load_dotenv("/home/kevin/projects/langgraph/.env")
# Out:
# True

# %%
DEFAULT_CONFIG = {
    "ocr": False,
    "coordinates": True,
    "output_formats": "['html', 'text', 'markdown']",
    "model": "document-parse",
    "base64_encoding": "['figure', 'chart', 'table']",
}

# %%
def upstage_layout_analysis(input_file):
    """
    Upstage의 Document Parse API를 호출하여 문서 분석을 수행합니다.

    :param input_file: 분석할 PDF 파일의 경로
    :return: 분석 결과가 저장된 JSON 파일의 경로
    """
    # API 요청 헤더 설정
    headers = {"Authorization": f"Bearer {os.getenv('UPSTAGE_API_KEY')}"}
    
    try:
        # 분석할 PDF 파일 열기
        with open(input_file, "rb") as file:
            files = {"document": file}
            
            # API 요청 보내기
            response = requests.post(
                "https://api.upstage.ai/v1/document-ai/document-parse",
                headers=headers,
                data=DEFAULT_CONFIG,
                files=files,
            )
            
            # 응답 상태 확인 및 디버깅
            print(f"응답 상태 코드: {response.status_code}")
            print(f"응답 내용: {response.text[:500]}...")  # 처음 500자만 출력
            
            # API 응답 처리 및 결과 저장
            if response.status_code == 200:
                output_file = os.path.splitext(input_file)[0] + ".json"
                
                # 응답 데이터 확인
                response_data = response.json()
                
                # 분석 결과를 JSON 파일로 저장
                with open(output_file, "w", encoding='utf-8') as f:
                    json.dump(response_data, f, ensure_ascii=False, indent=2)
                
                return output_file
            else:
                raise ValueError(f"API 요청 실패. 상태 코드: {response.status_code}, 응답: {response.text}")
                
    except Exception as e:
        print(f"에러 발생: {str(e)}")
        raise

# %%
response = upstage_layout_analysis("/home/kevin/projects/langgraph/data/01_(무)아이사랑첫보험 (1).pdf")
print(response)

# 저장된 JSON 파일 확인
with open(response, "r", encoding='utf-8') as f:
    data = json.load(f)
print(json.dumps(data, ensure_ascii=False, indent=2)[:1000])  # 처음 1000자만 출력
# Out:
# 응답 상태 코드: 200
# 응답 내용: {"api":"2.0","content":{"html":"<h1 id='0' style='font-size:20px'>무배당 아이사랑 첫보험</h1>\n<p id='1' data-category='paragraph' style='font-size:14px'>※ 본 상품은 보장성상품이며, 저축(연금)목적에는 적합하지 않습니다.</p>\n<figure><img id='2' alt=\"\" data-coord=\"top-left:(417,936); bottom-right:(1117,1485)\" /></figure>\n<p id='3' data-category='paragraph' style='font-size:16px'>※ 기타 자세한 사항은 보험 계약 체결 전, 상품설명서 및 약관을 반드시 읽어보시기</p>\n<br><footer id='4' style='font-size:16px'>바랍니다. 1</footer>\n<header id='5' style='font-size:16px'>메...
# /home/kevin/projects/langgraph/data/01_(무)아이사랑첫보험 (1).json
# {
#   "api": "2.0",
#   "content": {
#     "html": "<h1 id='0' style='font-size:20px'>무배당 아이사랑 첫보험</h1>\n<p id='1' data-category='paragraph' style='font-size:14px'>※ 본 상품은 보장성상품이며, 저축(연금)목적에는 적합하지 않습니다.</p>\n<figure><img id='2' alt=\"\" data-coord=\"top-left:(417,936); bottom-right:(1117,1485)\" /></figure>\n<p id='3' data-category='paragraph' style='font-size:16px'>※ 기타 자세한 사항은 보험 계약 체결 전, 상품설명서 및 약관을 반드시 읽어보시기</p>\n<br><footer id='4' style='font-size:16px'>바랍니다. 1</footer>\n<header id='5' style='font-size:16px'>메트라이프생명 무배당 아이사랑 첫보험</header>\n<h1 id='6' style='font-size:22px'>상품특징</h1>\n<p id='7' data-category='paragraph' style='font-size:20px'>태아와 산모 모두 보호해주니까 안심(해당 특약 가입시)</p>\n<br><p id='8' data-category='list' style='font-size:18px'>Ÿ (무)주요선천이상진단특약<br>Ÿ (무)주산기수술특약</p>\n<br><p id='9' data-category='list' style='font-size:18px'>Ÿ (무)산모보장특약<br>Ÿ (무)저체중아보장특약<br>Ÿ (무)주산기입원특약</p>\n<h1 id='10' style='font-size:20px'>큰 병도 보장해주니까 든든</h1>\n<br><p id='11' data-category='list' style='font-size:18px

# %%
from pprint import pprint
pprint(data)
# Out:
# {'api': '2.0',
#  'content': {'html': "<h1 id='0' style='font-size:20px'>무배당 아이사랑 첫보험</h1>\n"
#                      "<p id='1' data-category='paragraph' "
#                      "style='font-size:14px'>※ 본 상품은 보장성상품이며, 저축(연금)목적에는 적합하지 "
#                      '않습니다.</p>\n'
#                      '<figure><img id=\'2\' alt="" '
#                      'data-coord="top-left:(417,936); '
#                      'bottom-right:(1117,1485)" /></figure>\n'
#                      "<p id='3' data-category='paragraph' "
#                      "style='font-size:16px'>※ 기타 자세한 사항은 보험 계약 체결 전, 상품설명서 및 "
#                      '약관을 반드시 읽어보시기</p>\n'
#                      "<br><footer id='4' style='font-size:16px'>바랍니다. "
#                      '1</footer>\n'
#                      "<header id='5' style='font-size:16px'>메트라이프생명 무배당 아이사랑 "
#                      '첫보험</header>\n'
#                      "<h1 id='6' style='font-size:22px'>상품특징</h1>\n"
#                      "<p id='7' data-category='paragraph' "
#                      "style='font-size:20px'>태아와 산모 모두 보호해주니까 안심(해당 특약 "
#                      '가입시)</p>\n'
#                      "<br><p id='8' data-category='list' "
#                      "style='font-size:18px'>Ÿ (무)주요선천이상진단특약<br>Ÿ "
#                      '(무)주산기수술특약</p>\n'
#                      "<br><p id='9' data-category='list' "
#                      "style='font-size:18px'>Ÿ (무)산모보장특약<br>Ÿ (무)저체중아보장특약<br>Ÿ "
#                      '(무)주산기입원특약</p>\n'
#                      "<h1 id='10' style='font-size:20px'>큰 병도 보장해주니까 든든</h1>\n"
#                      "<br><p id='11' data-category='list' "
#                      "style='font-size:18px'>Ÿ 어린이 고액암 진단비 Ÿ CI 치료자금<br>Ÿ 중대한 "
#                      '수술비</p>\n'
#                      "<h1 id='12' style='font-size:20px'>질병 및 사고를 다양하게 "
#                      '보장</h1>\n'
#                      "<br><p id='13' data-category='list' "
#                      "style='font-size:18px'>Ÿ 암 진단비 Ÿ 질병 및 재해 수술비 / 입원비<br>Ÿ "
#                      '어린이 중요질환 수술비 / 입원비 Ÿ 어린이 생활질환 수술비 / 입원비<br>Ÿ 어린이 '
#                      '소액암진단비</p>\n'
#                      "<h1 id='14' style='font-size:20px'>고객 니즈에 따라 맞춤 선택 "
#                      '가능</h1>\n'
#                      "<br><p id='15' data-category='list' "
#                      "style='font-size:18px'>Ÿ 1종 : 순수보장형<br>Ÿ 2종 : 50% "
#                      '만기환급형</p>\n'
#                      "<p id='16' data-category='paragraph' "
#                      "style='font-size:20px'>만일의 경우 아이의 미래를 위한 학자금으로 활용<br>(해당 "
#                      '특약 가입시)</p>\n'
#                      "<br><p id='17' data-category='paragraph' "
#                      "style='font-size:18px'>Ÿ (무)보호자정기특약</p>\n"
#                      "<p id='18' data-category='paragraph' "
#                      "style='font-size:20px'>라이프사이클에 맞추어 다양한 헬스케어서비스 및<br>종합 "
#                      '은퇴 관리 서비스 제공</p>\n'
#                      '<figure><img id=\'19\' alt="" '
#                      'data-coord="top-left:(190,1300); '
#                      'bottom-right:(294,1413)" /></figure>\n'
#                      "<br><p id='20' data-category='paragraph' "
#                      "style='font-size:18px'>전문의료진 상담, 진료예약 및 명의안내는 물론, 가입금액에 "
#                      '따라 가족확대서비스와<br>같은 다양한 헬스케어서비스를 제공합니다. 또한 간병인 제공, 시니어를 '
#                      '위한<br>개인비서, 반려동물 헬스케어 등 든든하고 행복한 노후를 위한 차별화된 '
#                      '서비스를<br>제공합니다.</p>\n'
#                      "<br><p id='21' data-category='list' "
#                      "style='font-size:14px'>※ 헬스케어서비스는 보장성 상품 및 (무)변액연금보험 동행의 "
#                      '사망보장형 주계약 가입금액 합산액이<br>5천만원 이상인 피보험자에게 제공됩니다.<br>※ 만 15세 '
#                      '이후에 (무)아이사랑첫보험 유지 시 타 상품의 주계약 금액과 합산되어 헬스케어서비스가<br>제공될 수 '
#                      '있습니다.<br>※ 종합 은퇴 관리서비스(360Future)는 메트라이프생명 계약자 및 피보험자에게 '
#                      '제공합니다.<br>다만 360Future 프리미엄서비스는 회사에서 정한 보장성상품 주계약 합산 1억원 '
#                      '이상<br>저축성상품 월납 보험료 합산 100만원 이상 가입계약의 주피보험자에게 제공합니다.<br>※ '
#                      '자세한 서비스 내용은 메트라이프생명 홈페이지 및 MetLife One 앱을 참고하시기 '
#                      '바랍니다.<br>※ 본 서비스는 서비스 개선 및 대내외 환경 변화로 인해 향후 서비스 내용이 '
#                      '축소되거나 변경 될 수<br>있습니다.</p>\n'
#                      "<footer id='22' style='font-size:16px'>2</footer>\n"
#                      "<h1 id='23' style='font-size:20px'>보장내용</h1>\n"
#                      "<br><p id='24' data-category='paragraph' "
#                      "style='font-size:14px'>예시기준 : 주계약 가입금액 1,000만원</p>\n"
#                      "<br><table id='25' "
#                      "style='font-size:16px'><tr><td>구분</td><td>지급사유</td><td>지급금액</td></tr><tr><td>만기환급금</td><td>보험기간이 "
#                      '끝날 때까지 살아있을 때 (2종 50% 만기환급형만 해당)</td><td>이미 납입한 보혐료의 '
#                      '50%</td></tr><tr><td rowspan="2">암진단보험금</td><td>암 진단이 '
#                      '확정되었을 때 (최초 1회에 '
#                      '한함)</td><td>2,000만원</td></tr><tr><td>갑상선암, 기타피부암, 제자리암, '
#                      '경계성종양 진단이 확정되었을 때 (각각 최초 1회에 '
#                      '한함)</td><td>200만원</td></tr><tr><td '
#                      'rowspan="5">CI치료자금</td><td>말기신부전증으로 진단이 확정되었을 때 (최초 1회에 '
#                      '한함)</td><td>2,000만원</td></tr><tr><td>5대장기이식 수술을 받았을 때 '
#                      '(최초 1회에 한함)</td><td>3,000만원</td></tr><tr><td>중증 재생불량성빈혈 '
#                      '진단이 확정되었을 때 (최초 1회에 '
#                      '한함)</td><td>1,000만원</td></tr><tr><td>양성뇌종양으로 진단이 확정되었을 때 '
#                      '(최초 1회에 한함)</td><td>500만원</td></tr><tr><td>중대한 화상 및 부식으로 '
#                      '진단이 확정되었을 때 (최초 1회에 한함)</td><td>3,000만원</td></tr><tr><td '
#                      'rowspan="2">중대한 수술보험금</td><td>조혈모세포이식 수술을 받았을 때 (최초 1회에 '
#                      '한함)</td><td>2,000만원</td></tr><tr><td>중대한 재해로 인한 수술을 받았을 '
#                      '때 (수술 1회당)</td><td>300만원</td></tr><tr><td '
#                      'rowspan="2">어린이질환수술보험금</td><td>어린이 중요질환으로 인한 수술을 받았을 때 '
#                      '(수술 1회당)</td><td>200만원</td></tr><tr><td>어린이 생활질환으로 인한 '
#                      '수술을 받았을 때 (수술 '
#                      '1회당)</td><td>50만원</td></tr><tr><td>화상수술보험금</td><td>화상으로 '
#                      '인한 수술을 받았을 때 (수술 1회당)</td><td>50만원</td></tr><tr><td>질병 및 '
#                      '재해수술보험금</td><td>1~5종 수술분류표에서 정한 수술을 받았을 때 (수술 '
#                      '1회당)</td><td>1종 : 10만원, 2종 : 30만원, 3종 : 50만원, 4종 : '
#                      '100만원, 5종 : 300만원</td></tr><tr><td '
#                      'rowspan="2">어린이질환입원보험금</td><td>어린이 중요질환으로 입원하였을 때 3일 초과 '
#                      '1일당 (120일 한도)</td><td>4만원</td></tr><tr><td>어린이 생활질환으로 '
#                      '입원하였을 때 3일 초과 1일당 (120일 '
#                      '한도)</td><td>5천원</td></tr><tr><td>컴퓨터-미디어 '
#                      '관련질환입원보험금</td><td>컴퓨터-미디어 관련질환으로 입원하였을 때 3일 초과 1일당 (120일 '
#                      '한도)</td><td>1만원</td></tr><tr><td>질병 및 재해입원보험금</td><td>질병 '
#                      '또는 재해로 인해 입원하였을 때 3일 초과 1일당 (120일 '
#                      '한도)</td><td>2만원</td></tr><tr><td>주요 '
#                      '법정감염병치료비</td><td>주요법정감염병으로 해당 보건소에 신고되어 감염병 환자로 진단이 '
#                      '확정되었을 때 (발생 '
#                      '1회당)</td><td>50만원</td></tr><tr><td>깁스치료비</td><td>질병 또는 '
#                      '재해로 깁스치료를 받았을 때 (발생 '
#                      '1회당)</td><td>10만원</td></tr><tr><td>재해골절치료비</td><td>재해로 '
#                      '인한 골절(치아파절 제외) 상태가 되었을 때 (발생 '
#                      '1회당)</td><td>30만원</td></tr><tr><td>유괴납치 '
#                      '위로금</td><td>유괴·납치의 피해자가 되었을 때 (최초 1회에 한하며, 30세 계약해당일 '
#                      '전일까지만 보장)</td><td>500만원</td></tr><tr><td '
#                      'rowspan="2">재해장해보험금</td><td>교통재해로 장해상태가 되었을 '
#                      '때</td><td>1억원 × 해당장해지급률</td></tr><tr><td>교통재해 이외의 재해로 '
#                      '장해상태가 되었을 때</td><td>5,000만원 × 해당장해지급률</td></tr></table>\n'
#                      "<br><p id='26' data-category='footnote' "
#                      "style='font-size:14px'>Ÿ 보험료 납입면제 「암(갑상선암, 기타피부암, 제자리암 "
#                      '또는 경계성종양 제외)으로 진단 확정되었을 때」, 「말기신부전증으로 진단<br>확정되었을 때」 또는 '
#                      '「장해분류표 중 동일한 재해 또는 재해 이외의 동일한 원인으로 여러 신체부위의 장해지급률을 '
#                      '더하여<br>50%이상의 장해상태가 되었을 경우」에는 차회 이후의 보험료 납입이 면제됩니다. 단, '
#                      '태아보장기간에는 보험료 납입이 면제되지<br>않습니다.<br>Ÿ 피보험자가 사망한 경우에는 사망 '
#                      '당시의 계약자적립액을 지급하여 드리고 이 계약은 더 이상 효력을 가지지 아니합니다.<br>단, '
#                      '피보험자가 만 15세 미만 사망 시 이미 납입한 보험료와 계약자적립액 중 큰 금액을 '
#                      '지급합니다.</p>\n'
#                      "<p id='27' data-category='paragraph' "
#                      "style='font-size:16px'>※ 기타 자세한 사항은 보험 계약 체결 전, 상품설명서 및 "
#                      '약관을 반드시 읽어보시기 바랍니다.</p>\n'
#                      "<br><p id='28' data-category='paragraph' "
#                      "style='font-size:16px'>3</p>\n"
#                      "<header id='29' style='font-size:16px'>메트라이프생명 무배당 아이사랑 "
#                      '첫보험</header>\n'
#                      "<h1 id='30' style='font-size:20px'>가입안내</h1>\n"
#                      "<table id='31' style='font-size:16px'><tr><td "
#                      'rowspan="2">상품유형</td><td colspan="2">1종 : 순수보장형</td><td '
#                      'colspan="2">2종 : 50% '
#                      '만기환급형</td></tr><tr><td>태아형</td><td>어린이형</td><td>태아형</td><td>어린이형</td></tr><tr><td>보험기간</td><td '
#                      'colspan="2">30세 만기, 40세 만기</td><td colspan="2">40세 '
#                      '만기</td></tr><tr><td>가입나이</td><td '
#                      'colspan="4">태아~15세(납입기간에 따라 '
#                      '다름)</td></tr><tr><td>납입기간</td><td '
#                      'colspan="4">태아(1개월~10개월) : 전기납 10년납, 15년납, '
#                      '20년납</td></tr><tr><td>가입금액</td><td colspan="4">최저 '
#                      '1,000만원 ~ 최고 2,000만원(100만원 '
#                      '단위)</td></tr><tr><td>납입주기</td><td '
#                      'colspan="4">월납</td></tr></table>\n'
#                      "<br><p id='32' data-category='list' "
#                      "style='font-size:14px'>Ÿ 가입나이 및 가입한도 등의 계약인수 관련 사항은 회사가 "
#                      '정한 기준에 따라 제한될 수 있습니다.<br>Ÿ 피보험자로 될 자가 태아인 경우 계약일부터 '
#                      '출생시점(출산 또는 분만과정에서 보험금 지급사유가 발생하는 경우 포함)까지의 '
#                      '기간을<br>태아보장기간으로 하여 1개월 ~ 10개월의 보험기간 및 보험료납입기간을 추가로 '
#                      '부가합니다.</p>\n'
#                      "<figure><img id='33' style='font-size:16px' "
#                      'alt="태아형이란?\n'
#                      '(무)아이사랑첫보험은 태아를 피보험자로 할 수 있습니다. 태아보장기간은 계약일로부터\n'
#                      '출생시점(출산 또는 분만과정에서 보험금 지급사유가 발생하는 경우 포함)까지이고, 이때 보험료는\n'
#                      '남자 보험료를 적용합니다. 출생예정일이 도래한 경우, 차회 이후의 보험료는 보험나이 0세 기준으로\n'
#                      '변경하여 적용하며, 출생한 피보험자의 성별이 변경되거나 계약체결 시 출생예정일과 실제출생일이 다른\n'
#                      '경우에는 보험료 및 해약환급금 산출방법서에서 정한 방법에 따라 해당 보험료를 정산합니다.\n'
#                      '피보험자가 태아인 경우, 어린이형 보험기간은 출생시점부터 계약자가 선택한 기간을 말합니다.\n'
#                      '태아보장기간 이후에도 태아보장기간 중에 발생한 위험을 원인으로 보험금 지급사유가 발생하는 경우\n'
#                      '보험금을 지급합니다." data-coord="top-left:(150,744); '
#                      'bottom-right:(1086,1320)" /></figure>\n'
#                      "<footer id='34' style='font-size:16px'>4</footer>\n"
#                      "<h1 id='35' style='font-size:20px'>보험료 예시</h1>\n"
#                      '\n'
#                      "<br><table id='37' style='font-size:18px'><tr><td "
#                      'rowspan="2">가입나이</td><td>남자</td><td>여자</td></tr><tr><td>1종 '
#                      '순수보장형 2종 50% 만기환급형</td><td>1종 순수보장형 2종 50% '
#                      '만기환급형</td></tr><tr><td>태아(1개월~10개월)</td><td>8,600</td><td>8,600</td></tr><br><caption '
#                      "id='36' style='font-size:14px'>예시기준 : 주계약 가입금액 1,000만원, "
#                      '전기납, 월납/ 단위 : 원</caption></table>\n'
#                      "<p id='38' data-category='paragraph' "
#                      "style='font-size:14px'>예시기준 : 주계약 가입금액 1,000만원, 40세 만기, "
#                      '월납/ 단위 : 원</p>\n'
#                      "<br><table id='39' style='font-size:16px'><tr><td "
#                      'rowspan="3">가입나이</td><td colspan="4">남자</td><td '
#                      'colspan="4">여자</td></tr><tr><td colspan="2">1종 '
#                      '순수보장형</td><td colspan="2">2종 50% 만기환급형</td><td '
#                      'colspan="2">1종 순수보장형</td><td colspan="2">2종 50% '
#                      '만기환급형</td></tr><tr><td>10년납</td><td>20년납</td><td>10년납</td><td>20년납</td><td>10년납</td><td>20년납</td><td>10년납</td><td>20년납</td></tr><tr><td>0세</td><td>27,800</td><td>17,800</td><td>43,200</td><td>29,000</td><td>25,800</td><td>16,600</td><td>40,000</td><td>27,200</td></tr><tr><td>5세</td><td>26,100</td><td>16,800</td><td>43,400</td><td>29,800</td><td>24,300</td><td>15,800</td><td>40,400</td><td>28,000</td></tr><tr><td>10세</td><td>25,700</td><td>16,600</td><td>46,400</td><td>32,300</td><td>24,100</td><td>15,700</td><td>43,700</td><td>30,700</td></tr></table>\n'
#                      "<br><p id='40' data-category='paragraph' "
#                      "style='font-size:14px'>• 위의 보험료는 가입나이, 성별, 보험기간 및 납입기간 "
#                      '등에 따라 달라질 수 있습니다.</p>\n'
#                      "<h1 id='41' style='font-size:20px'>해약환급금 예시</h1>\n"
#                      '\n'
#                      "<br><table id='43' style='font-size:16px'><tr><td "
#                      'rowspan="2">경과기간</td><td colspan="3">1종 순수보장형 '
#                      '(20년납)</td><td colspan="3">2종 50% 만기환급형 '
#                      '(20년납)</td></tr><tr><td>납입보험료</td><td>해약환급금</td><td>환급률</td><td>납입보험료</td><td>해약환급금</td><td>환급률</td></tr><tr><td>1년</td><td>20</td><td>0</td><td>0%</td><td>35</td><td>0</td><td>0%</td></tr><tr><td>3년</td><td>60</td><td>4</td><td>7%</td><td>107</td><td>30</td><td>28%</td></tr><tr><td>5년</td><td>100</td><td>20</td><td>20%</td><td>178</td><td>70</td><td>39%</td></tr><tr><td>10년</td><td>201</td><td>51</td><td>25%</td><td>357</td><td>164</td><td>46%</td></tr><tr><td>15년</td><td>302</td><td>77</td><td>25%</td><td>536</td><td>257</td><td>48%</td></tr><tr><td>20년</td><td>403</td><td>102</td><td>25%</td><td>715</td><td>356</td><td>50%</td></tr><tr><td>25년</td><td>403</td><td>81</td><td>20%</td><td>715</td><td>366</td><td>51%</td></tr><tr><td>30년</td><td>403</td><td>75</td><td>19%</td><td>715</td><td>367</td><td>51%</td></tr><tr><td>35년</td><td>403</td><td>69</td><td>17%</td><td>715</td><td>367</td><td>51%</td></tr><br><caption '
#                      "id='42' style='font-size:14px'>예시기준 : 주계약 가입금액 1,000만원, "
#                      '5세 남자, 40세 만기 / 단위 : 만원, 만원 미만 절사</caption></table>\n'
#                      "<br><p id='44' data-category='list' "
#                      "style='font-size:14px'>• 보험계약자가 기존에 체결했던 보험계약을 해지하고 다른 "
#                      '보험계약을 체결하면, 보험인수가 거절되거나 보험료가 인상 또는 보장내용이<br>달라질 수 '
#                      '있습니다.<br>• 해약환급금은 이미 납입한 보험료보다 적거나 없을 수 있으며, 기타 보험료 및 '
#                      '해약환급금 산출 관련 사항은 상품요약서(당사 홈페이지<br>상품공시실 참조) 및 상품설명서에서 보다 '
#                      '자세히 확인하실 수 있습니다.<br>• 상기 해약환급금은 세전기준입니다.</p>\n'
#                      "<footer id='45' style='font-size:16px'>※ 기타 자세한 사항은 보험 "
#                      '계약 체결 전, 상품설명서 및 약관을 반드시 읽어보시기 바랍니다.</footer>\n'
#                      "<br><p id='46' data-category='paragraph' "
#                      "style='font-size:16px'>5</p>\n"
#                      "<header id='47' style='font-size:16px'>메트라이프생명 무배당 아이사랑 "
#                      '첫보험</header>\n'
#                      "<h1 id='48' style='font-size:20px'>부가가능특약</h1>\n"
#                      "<table id='49' "
#                      "style='font-size:16px'><tr><td>태아관련특약</td><td>산모보장관련특약</td><td>사망관련특약</td><td>질병관련특약</td><td>기타특약</td></tr><tr><td>(무)주산기수술특약 "
#                      '(태아가입 시 의무부가) (무)주산기입원특약 (태아가입 시 의무부가) (무)주요선천이상진단특약 '
#                      '(무)저체중아보장특약</td><td>(무)산모보장특약</td><td>(무)보호자정기특약</td><td>(무)어린이 '
#                      '암진단특약 (무)어린이 고액암진단특약 (무)어린이 소액암진단특약</td><td>지정대리청구 '
#                      '서비스특약</td></tr></table>\n'
#                      "<br><p id='50' data-category='list' "
#                      "style='font-size:14px'>Ÿ 가입나이, 가입한도, 특약부가조건 등의 계약인수 관련 "
#                      '사항은 회사가 정한 기준에 따라 제한될 수 있습니다.<br>Ÿ 특약 가입 여부는 보험계약 성립에 '
#                      '영향을 미치지 않습니다.<br>Ÿ 태아관련특약은 보험기간 중 피보험자(태아) 출생 후 '
#                      '보장됩니다.<br>Ÿ (무)주산기수술특약 및 (무)주산기입원특약은 태아가입 시에만 '
#                      '의무부가됩니다.<br>Ÿ 산모보장관련특약의 경우 가입대상은 임신 0주부터 임신 23주 이내에 있는 '
#                      '임산부로 합니다.<br>Ÿ 태아관련특약 및 산보보장관련 특약의 보험기간 : 1년 만기<br>Ÿ '
#                      '(무)보호자정기특약 보험기간 : 자녀나이 30세 만기 시점까지<br>Ÿ (무)어린이암진단특약, '
#                      '(무)어린이고액암진단특약, (무)어린이소액암진단특약 보험기간 : 30세 만기<br>Ÿ 주계약의 보험료 '
#                      '납입이 면제되었을 경우에는 부가특약의 보험료 납입을 면제해 드립니다.<br>Ÿ 태아보장기간에는 보험료 '
#                      '납입이 면제되지 않습니다.<br>Ÿ (무)어린이암진단특약과 (무)어린이소액암진단특약은 동시에 '
#                      '가입하여야 하며, 가입금액은 동일하게 가입하여야 합니다.</p>\n'
#                      "<footer id='51' style='font-size:16px'>6</footer>\n"
#                      "<h1 id='52' style='font-size:20px'>태아관련특약</h1>\n"
#                      "<table id='53' "
#                      "style='font-size:16px'><tr><td>특약명</td><td>(무)주산기수술특약(태아가입 "
#                      '시 의무부가) (무)주산기입원특약(태아가입 시 의무부가) (무)주요선천이상진단특약 '
#                      '(무)저체중아보장특약</td></tr><tr><td>보험기간</td><td>1년</td></tr><tr><td>납입기간</td><td>전기납(1년납)</td></tr><tr><td>가입나이</td><td>임신 '
#                      '0주~35주(단, 산모가 40세 이상일 경우 16주~35주) (무)저체중아보장특약의 경우 임신 23주 '
#                      '이내</td></tr></table>\n'
#                      "<p id='54' data-category='paragraph' "
#                      "style='font-size:14px'>예시기준 : 특약별 가입금액 1,000만원</p>\n"
#                      "<br><table id='55' "
#                      "style='font-size:16px'><tr><td>구분</td><td>가입금액한도</td><td>보장내용</td><td>지급사유</td><td>지급금액</td></tr><tr><td>(무)주산기수술특약 "
#                      '(태아가입 시 의무부가)</td><td>500만원 ~ 1,000만원</td><td>주산기 '
#                      '수술보험금</td><td>보험기간 중 피보험자가 출생 후 주산기질환으로 진단이 확정되고 그 치료를 '
#                      '직접적인 목적으로 수술을 받았을 때</td><td>25만원 / 수술 '
#                      '1회당</td></tr><tr><td>(무)주산기입원특약 (태아가입 시 '
#                      '의무부가)</td><td>500만원 ~ 1,000만원</td><td>주산기 '
#                      '입원보험금</td><td>보험기간 중 피보험자가 출생 후 주산기질환으로 진단이 확정되고 그 치료를 '
#                      '직접적인 목적으로 4일 이상 계속 입원하였을 때 (1회 입원당 120일 한도)</td><td>1만원 '
#                      '/ 3일 초과 입원 1일당</td></tr><tr><td '
#                      'rowspan="3">(무)주요선천이상진단특약</td><td rowspan="3">500만원 ~ '
#                      '1,000만원</td><td rowspan="3">주요선천이상 진단보험금</td><td>보험기간 중 '
#                      '피보험자가 출생 후 [3대 주요 선천이상]으로 진단 확정되었을 때(최초 1회에 '
#                      '한함)</td><td>500만원</td></tr><tr><td>보험기간 중 피보험자가 출생 후 '
#                      '[언청이(구순구개열)]로 진단 확정되었을 때(최초 1회에 '
#                      '한함)</td><td>200만원</td></tr><tr><td>보험기간 중 피보험자가 출생 후 '
#                      '[다지증]으로 진단 확정되었을 때 (최초 1회에 '
#                      '한함)</td><td>100만원</td></tr><tr><td '
#                      'rowspan="2">(무)저체중아보장특약</td><td rowspan="2">500만원 ~ '
#                      '1,000만원</td><td rowspan="2">저체중아 보육보험금</td><td>아기의 출생 시 '
#                      '체중이 1.5kg 미만일 경우</td><td>200만원</td></tr><tr><td>아기의 출생 시 '
#                      '체중이 1.5kg 이상 2.0kg 미만일 '
#                      '경우</td><td>100만원</td></tr></table>\n'
#                      "<br><p id='56' data-category='footnote' "
#                      "style='font-size:14px'>Ÿ (무)주산기수술특약, (무)주산기입원특약, "
#                      '(무)주요선천이상진단특약의 경우, 특약의 보험기간이 종료된 경우라도 피보험자의 '
#                      '출생일로부터<br>1년이 되는 시점의 전날까지 해당 보험금 지급사유가 발생한 경우에는 보험금을 '
#                      '지급합니다.<br>Ÿ (무)주요선천이상진단특약에서 보장하는 [3대 주요선천이상]이란, 척추갈림증, '
#                      '팔로 네징후, 다운증후군을 말합니다.</p>\n'
#                      "<p id='57' data-category='paragraph' "
#                      "style='font-size:16px'>※ 기타 자세한 사항은 보험 계약 체결 전, 상품설명서 및 "
#                      '약관을 반드시 읽어보시기 바랍니다.</p>\n'
#                      "<br><p id='58' data-category='paragraph' "
#                      "style='font-size:16px'>7</p>\n"
#                      "<header id='59' style='font-size:16px'>메트라이프생명 무배당 아이사랑 "
#                      '첫보험</header>\n'
#                      "<h1 id='60' style='font-size:20px'>산모관련특약</h1>\n"
#                      "<br><p id='61' data-category='paragraph' "
#                      "style='font-size:14px'>예시기준 : 특약별 가입금액 1,000만원</p>\n"
#                      "<br><table id='62' "
#                      "style='font-size:16px'><tr><td>구분</td><td>가입금액한도</td><td>보장내용</td><td>지급사유</td><td>지급금액</td></tr><tr><td "
#                      'rowspan="3">(무)산모보장특약</td><td rowspan="3">500만원 ~ '
#                      '1,000만원</td><td>모성사망 보험금</td><td>모성사망을 직접적인 원인으로 사망하였을 '
#                      '때</td><td>5,000만원</td></tr><tr><td>임신출산관련 질환 '
#                      '수술보험금</td><td>임신ž출산관련질환으로 진단이 확정되고 그 치료를 직접목적으로 수술을 받았을 '
#                      '때</td><td>20만원 / 수술 1회당</td></tr><tr><td>유산관련질환 '
#                      '수술보험금</td><td>유산관련질환으로 진단이 확정되고 그 치료를 직접목적으로 수술을 받았을 '
#                      '때</td><td>10만원 / 수술 1회당</td></tr></table>\n'
#                      "<br><p id='63' data-category='paragraph' "
#                      "style='font-size:14px'>Ÿ (무)산모보장특약의 보험기간(1년)에도 불구하고 이 "
#                      '특약의 보장은 계약일부터 임신종료 후 42일까지로 합니다.</p>\n'
#                      "<h1 id='64' style='font-size:20px'>사망관련특약</h1>\n"
#                      "<br><p id='65' data-category='paragraph' "
#                      "style='font-size:14px'>예시기준 : 특약별 가입금액 1,000만원</p>\n"
#                      "<br><table id='66' "
#                      "style='font-size:16px'><tr><td>구분</td><td>가입금액한도</td><td>보장내용</td><td>지급사유</td><td>지급금액</td></tr><tr><td>(무)보호자정기특약</td><td>500만원 "
#                      '~ 5,000만원</td><td>사망보험금</td><td>보험기간 중 (무)보호자정기특약의 피보험자가 '
#                      '사망하였을 경우</td><td>1,000만원</td></tr></table>\n'
#                      "<br><p id='67' data-category='list' "
#                      "style='font-size:14px'>Ÿ 고의적 사고 및 2년 이내 자살의 경우 사망보험금 지급이 "
#                      '제한됩니다.<br>Ÿ 태아형으로 가입하는 경우 특약의 피보험자는 태아를 임신한 임산부(임신 0주부터 '
#                      '임신 35주 이내)로 하며, 예약가입합니다.<br>Ÿ 특약의 보장개시 및 보험료 납입은 태아의 '
#                      '출생일부터 입니다.</p>\n'
#                      "<h1 id='68' style='font-size:20px'>질병관련특약</h1>\n"
#                      "<br><p id='69' data-category='paragraph' "
#                      "style='font-size:14px'>예시기준 : 특약별 가입금액 1,000만원</p>\n"
#                      "<br><table id='70' "
#                      "style='font-size:16px'><tr><td>구분</td><td>가입금액한도</td><td>보장내용</td><td>지급사유</td><td>지급금액</td></tr><tr><td>(무)어린이암진단특약</td><td>1,000만원 "
#                      '~ 3,000만원</td><td>암진단보험금</td><td>암으로 진단 확정되었을 때 (최초 1회에 '
#                      '한함)</td><td>1,000만원</td></tr><tr><td>(무)어린이고액암진단특약</td><td>500만원 '
#                      '~ 2,500만원</td><td>고액치료비 관련 암진단보험금</td><td>고액치료비암으로 진단 '
#                      '확정되었을 때 (최초 1회에 '
#                      '한함)</td><td>2,000만원</td></tr><tr><td>(무)어린이소액암진단특약</td><td>1,000만원 '
#                      '~ 3,000만원</td><td>소액암진단 보험금</td><td>보험기간 중 [기타피부암], '
#                      '[갑상선암], [제자리암] 또는 [경계성종양]으로 진단 확정 되었을 때 (각각 최초 1회에 '
#                      '한함)</td><td>100만원</td></tr></table>\n'
#                      "<footer id='71' style='font-size:16px'>8</footer>\n"
#                      "<h1 id='72' style='font-size:20px'>특약보험료 예시</h1>\n"
#                      "<br><p id='73' data-category='paragraph' "
#                      "style='font-size:14px'>예시기준: 특약별 가입금액 1,000만원, 월납 / 단위: "
#                      '원</p>\n'
#                      "<br><table id='74' "
#                      "style='font-size:16px'><tr><td>특약명</td><td>보험기간</td><td>납입기간</td><td>남자(태아)</td><td>여자(태아)</td></tr><tr><td>(무)주산기수술특약 "
#                      '(태아 가입시 의무부가)</td><td>1년</td><td>전기납 '
#                      '(1년납)</td><td>300</td><td>200</td></tr><tr><td>(무)주산기입원특약 '
#                      '(태아 가입시 의무부가)</td><td>1년</td><td>전기납 '
#                      '(1년납)</td><td>1,900</td><td>1,600</td></tr><tr><td>(무)주요선천이상진단특약</td><td>1년</td><td>전기납 '
#                      '(1년납)</td><td>2,600</td><td>2,700</td></tr></table>\n'
#                      "<p id='75' data-category='paragraph' "
#                      "style='font-size:14px'>예시기준: 특약별 가입금액 1,000만원, 월납 / 단위: "
#                      '원</p>\n'
#                      "<br><table id='76' style='font-size:16px'><tr><td "
#                      'rowspan="2">특약명</td><td rowspan="2">보험기간</td><td '
#                      'rowspan="2">납입기간</td><td '
#                      'colspan="4">여자(산모나이)</td></tr><tr><td>25세</td><td>30세</td><td>35세</td><td>40세</td></tr><tr><td>(무)저체중아보장특약</td><td>1년</td><td>전기납 '
#                      '(1년납)</td><td>3,100</td><td>3,700</td><td>5,400</td><td>6,500</td></tr><tr><td>(무)산모보장특약</td><td>1년</td><td>전기납 '
#                      '(1년납)</td><td>5,100</td><td>5,200</td><td>7,300</td><td>13,100</td></tr></table>\n'
#                      "<p id='77' data-category='paragraph' "
#                      "style='font-size:14px'>예시기준: 특약별 가입금액 1,000만원, 월납 / 단위: "
#                      '원</p>\n'
#                      "<br><table id='78' style='font-size:16px'><tr><td "
#                      'rowspan="2">특약명</td><td rowspan="2">보험기간</td><td '
#                      'rowspan="2">납입기간</td><td colspan="4">남자(보호자 나이)</td><td '
#                      'colspan="4">여자(보호자 '
#                      '나이)</td></tr><tr><td>25세</td><td>30세</td><td>35세</td><td>40세</td><td>25세</td><td>30세</td><td>35세</td><td>40세</td></tr><tr><td '
#                      'rowspan="2">(무)보호자정기특약</td><td>30년</td><td>10년납</td><td>3,000</td><td>4,500</td><td>7,000</td><td>10,900</td><td>1,900</td><td>2,500</td><td>3,400</td><td>4,900</td></tr><tr><td>30년</td><td>20년납</td><td>1,700</td><td>2,500</td><td>3,900</td><td>6,000</td><td>1,000</td><td>1,400</td><td>1,900</td><td>2,700</td></tr></table>\n'
#                      "<p id='79' data-category='paragraph' "
#                      "style='font-size:14px'>예시기준: 특약별 가입금액 1,000만원, 월납 / 단위: "
#                      '원</p>\n'
#                      "<br><table id='80' style='font-size:16px'><tr><td "
#                      'rowspan="2">특약명</td><td rowspan="2">보험기간</td><td '
#                      'rowspan="2">납입기간</td><td colspan="3">남자(아이 나이)</td><td '
#                      'colspan="3">여자(아이 '
#                      '나이)</td></tr><tr><td>0세</td><td>5세</td><td>10세</td><td>0세</td><td>5세</td><td>10세</td></tr><tr><td '
#                      'rowspan="2">(무)어린이암진단특약</td><td>30년</td><td>10년납</td><td>1,200</td><td>900</td><td>800</td><td>1,000</td><td>800</td><td>700</td></tr><tr><td>30년</td><td>20년납</td><td>600</td><td>500</td><td>400</td><td>500</td><td>400</td><td>400</td></tr><tr><td '
#                      'rowspan="2">(무)어린이고액암진단특약</td><td>30년</td><td>10년납</td><td>1,400</td><td>1,200</td><td>1,000</td><td>900</td><td>700</td><td>600</td></tr><tr><td>30년</td><td>20년납</td><td>800</td><td>600</td><td>500</td><td>500</td><td>400</td><td>300</td></tr><tr><td '
#                      'rowspan="2">(무)어린이소액암진단특약</td><td>30년</td><td>10년납</td><td>45</td><td>44</td><td>45</td><td>136</td><td>145</td><td>156</td></tr><tr><td>30년</td><td>20년납</td><td>25</td><td>24</td><td>25</td><td>75</td><td>80</td><td>86</td></tr></table>\n'
#                      "<br><p id='81' data-category='paragraph' "
#                      "style='font-size:14px'>Ÿ 태아형으로 가입하는 경우 보험료 예시(가입금액 "
#                      '1,000만원기준, 전기납)<br>(무)어린이암진단특약: 남아 400원/여아 300원, '
#                      '(무)어린이고액암진단특약: 남아 300원/여아 200원, (무)어린이소액암진단특약: '
#                      '남아<br>6원/여아 7원</p>\n'
#                      "<p id='82' data-category='paragraph' "
#                      "style='font-size:16px'>※ 기타 자세한 사항은 보험 계약 체결 전, 상품설명서 및 "
#                      '약관을 반드시 읽어보시기 바랍니다.</p>\n'
#                      "<br><p id='83' data-category='paragraph' "
#                      "style='font-size:16px'>9</p>\n"
#                      "<header id='84' style='font-size:16px'>메트라이프생명 무배당 아이사랑 "
#                      '첫보험</header>\n'
#                      "<h1 id='85' style='font-size:20px'>가입 시 안내 사항</h1>\n"
#                      "<h1 id='86' style='font-size:18px'>설명을 받을 수 있는 권리</h1>\n"
#                      "<br><p id='87' data-category='paragraph' "
#                      "style='font-size:14px'>회사는 해당 상품에 대해 충분히 설명할 의무가 있으며, "
#                      '가입자는<br>가입에 앞서 이에 대한 충분한 설명을 받으시기 바랍니다.</p>\n'
#                      "<h1 id='88' style='font-size:18px'>청약할 때 보험계약 확인</h1>\n"
#                      "<br><p id='89' data-category='paragraph' "
#                      "style='font-size:14px'>계약 청약 시 보험상품명, 보험기간, 보험료, 보험료 "
#                      '납입기간,<br>피보험자 등을 반드시 확인하시고 보험상품 내용을 설명 받으시기<br>바랍니다. 또한 '
#                      '해당 보험약관을 참조하시기 바랍니다.</p>\n'
#                      "<h1 id='90' style='font-size:18px'>계약 전 알릴 의무 및 "
#                      '자필서명</h1>\n'
#                      "<br><p id='91' data-category='paragraph' "
#                      "style='font-size:14px'>계약자 또는 피보험자는 보험계약을 청약할 때 청약서에 "
#                      '질문한<br>사항(계약 전 알릴 사항)에 대하여 사실대로 알려야 하며 보험계약자<br>및 피보험자는 '
#                      '청약서상의 자필서명란에 반드시 본인이 자필서명을<br>하셔야 합니다. 그렇지 않은 경우 보험금의 '
#                      '지급이 거절되거나<br>계약이 무효로 처리될 수 있습니다.</p>\n'
#                      "<h1 id='92' style='font-size:18px'>청약철회 청구제도</h1>\n"
#                      "<br><p id='93' data-category='paragraph' "
#                      "style='font-size:14px'>계약자는 보험증권을 받은 날부터 15일 이내에 그 청약을 "
#                      '철회할 수<br>있습니다. 단, 회사가 건강상태 진단을 지원하는 계약, 보험기간이<br>90일 이내인 '
#                      '계약, 전문금융소비자가 체결한 계약 또는 청약한<br>날부터 30일이 초과된 계약의 경우에는 청약을 '
#                      '철회할 수 없습니다.</p>\n'
#                      "<h1 id='94' style='font-size:18px'>품질 보증 제도</h1>\n"
#                      "<br><p id='95' data-category='paragraph' "
#                      "style='font-size:14px'>청약서상에 자필서명, 계약자 보관용 청약서 및 약관전달과 "
#                      '약관의<br>주요내용 설명 등을 이행하지 않은 계약에 대하여는 계약자가<br>계약성립일로부터 3개월 '
#                      '이내에 계약을 취소할 수 있습니다.</p>\n'
#                      "<h1 id='96' style='font-size:18px'>보험료의 납입이 연체되는 경우 "
#                      '보험계약의 해지</h1>\n'
#                      "<br><p id='97' data-category='paragraph' "
#                      "style='font-size:14px'>보험계약자가 보험료의 납입을 연체하는 경우 회사는 14일 "
#                      '이상의<br>납입최고(독촉)기간 동안(보험기간이 1년 미만인 경우에는 7일)<br>연체보험료를 '
#                      '납입하여야 한다는 내용과 납입최고(독촉)기간이<br>끝나는 날까지 보험료가 납입되지 않은 경우 '
#                      '납입최고(독촉)기간이<br>끝나는 날의 다음 날부터 계약이 해지됨을 알려드립니다. 단, '
#                      '해지<br>전에 발생한 보험금 지급사유에 대하여 회사는 약정한 보험금을<br>지급하여 '
#                      '드립니다.</p>\n'
#                      "<h1 id='98' style='font-size:18px'>세제 혜택</h1>\n"
#                      "<br><p id='99' data-category='paragraph' "
#                      "style='font-size:14px'>보장성 계약의 경우 근로소득자가 기본공제대상자를 "
#                      '피보험자로<br>하여 이 보험에 가입한 경우에는 당해년도에 납입하신 보장성<br>보험료에 대해서 연 '
#                      '100만원까지 세액공제 혜택을 받으실 수<br>있습니다.</p>\n'
#                      "<br><p id='100' data-category='paragraph' "
#                      "style='font-size:14px'>※ 세제와 관련된 사항은 관련 세법의 제·개정이나 폐지에 "
#                      '따라<br>변경될 수 있습니다.</p>\n'
#                      "<br><p id='101' data-category='paragraph' "
#                      "style='font-size:18px'>예금자보호 안내</p>\n"
#                      "<br><p id='102' data-category='paragraph' "
#                      "style='font-size:14px'>이 보험계약은 예금자보호법에 따라 해약환급금(또는 만기 "
#                      '시<br>보험금)에 기타지급금을 합한 금액이 1인당 “5천만원까지”(본<br>보험회사의 여타 '
#                      '보호상품과 합산) 보호됩니다. 이와 별도로 본<br>보험회사 보호상품의 사고보험금을 합산한 금액이 '
#                      '1인당<br>“5천만원까지” 보호됩니다. 단, 보험계약자 및 보험료 납부자가<br>법인이면 보호되지 '
#                      '않습니다.</p>\n'
#                      "<p id='103' data-category='paragraph' "
#                      "style='font-size:18px'>보험료 선납</p>\n"
#                      "<br><p id='104' data-category='paragraph' "
#                      "style='font-size:14px'>보험료의 선납은 당월분을 포함하여 최대 12개월분 "
#                      '이하의<br>보험료에 한하여 가능합니다. 보험료를 선납할 때의 할인은<br>3개월분 이상의 선납에 '
#                      '대해서 적용하며, 선납할 때에 적용하는<br>할인율은 이 계약 체결시점의 평균공시이율이 아닌 '
#                      '선납신청시점의<br>평균공시이율로 계산합니다. 선납 신청시점의 평균공시이율은<br>계약체결시점과 달리 '
#                      '변동 될 수 있습니다. 단, 태아를 피보험자로<br>한 경우에는 출생통지에 따른 확정이 이루어지기 '
#                      '전까지 보험료<br>선납이 제한됩니다.</p>\n'
#                      "<p id='105' data-category='paragraph' "
#                      "style='font-size:18px'>민생안정을 위한 보험료납입유예 안내</p>\n"
#                      "<br><p id='106' data-category='paragraph' "
#                      "style='font-size:14px'>보험계약자는 계약일로부터 경과기간 1년이 지난 이후부터 "
#                      '아래의<br>회사가 정한 사유에 해당하는 경우 주계약 및 특약 보험료 납입의<br>유예를 회사가 정한 '
#                      '방법에 따라 주계약의 보험료 납입기간 중<br>1회에 한하여 신청할 수 있습니다. (단, 납입기간 '
#                      '이후, 비갱신형<br>상품의 전기납 선택 시, 변액보험 및 외화보험의 경우에는 신청할 '
#                      '수<br>없습니다.)</p>\n'
#                      "<br><p id='107' data-category='list' "
#                      "style='font-size:14px'>- 『고용보험법』 제2조(정의) 제4호에 따른 실업의 인정을 "
#                      '받은 경우<br>- 3대 중대질병(암, 뇌출혈 및 뇌경색증, 급성심근경색) 진단<br>- 출산 또는 '
#                      '육아휴직(육아기 근로시간 단축 포함)<br>※ 보다 자세한 사항은 관련 약관을 참조하시기 '
#                      '바랍니다.</p>\n'
#                      "<p id='108' data-category='paragraph' "
#                      "style='font-size:18px'>기존계약 해지 후 신계약 체결시 불이익 사항</p>\n"
#                      "<br><p id='109' data-category='paragraph' "
#                      "style='font-size:14px'>보험계약자가 기존에 체결했던 보험계약을 해지하고 "
#                      '다른<br>보험계약을 체결하면, 보험인수가 거절되거나 보험료가 인상 또는<br>보장내용이 달라질 수 '
#                      '있습니다.</p>\n'
#                      "<p id='110' data-category='paragraph' "
#                      "style='font-size:18px'>해약환급금이 납입보험료 보다 적은 이유</p>\n"
#                      "<br><p id='111' data-category='paragraph' "
#                      "style='font-size:14px'>계약자가 납입한 보험료는 불의의 사고를 당한 다른 "
#                      '가입자에게<br>보험금으로 지급되고 보험회사 운영에 필요한 경비로 사용되므로<br>중도 해지하는 경우 '
#                      '지급되는 해약환급금은 납입한 보험료보다<br>적거나 없을 수 있습니다.</p>\n'
#                      "<p id='112' data-category='paragraph' "
#                      "style='font-size:18px'>보험 분쟁 및 상담안내</p>\n"
#                      "<br><p id='113' data-category='paragraph' "
#                      "style='font-size:14px'>생명보험에 대해 궁금하시거나 불만사항이 있는 "
#                      '경우<br>메트라이프생명 콜센터(1588-9600)로 문의하시면 성실히 안내해<br>드리겠습니다. '
#                      '또한, 당사 상담결과에 이의가 있으시면 금융감독원<br>(국번없이 1332, '
#                      'www.fss.or.kr)에 민원 또는 분쟁조정을<br>신청하실 수 있습니다.</p>\n'
#                      "<p id='114' data-category='paragraph' "
#                      "style='font-size:18px'>보험계약 관련 조회시스템 운영</p>\n"
#                      "<br><p id='115' data-category='paragraph' "
#                      "style='font-size:14px'>계약자께서는 본 상품에 대한 자세한 내용과 본 "
#                      '상품으로<br>보험설계를 하실 경우 또는 당사의 상품과 유사한 다른 회사의<br>상품을 비교하실 경우 '
#                      '아래 인터넷 사이트를 통해 확인하실 수<br>있습니다.</p>\n'
#                      "<br><p id='116' data-category='paragraph' "
#                      "style='font-size:14px'>• 보험상품 및 가격공시실 : "
#                      'www.metlife.co.kr (당사 홈페이지)<br>• 보험상품 비교·공시 : '
#                      'www.klia.or.kr (생명보험협회 홈페이지)</p>\n'
#                      "<footer id='117' style='font-size:16px'>10</footer>\n"
#                      '<figure><img id=\'118\' alt="" '
#                      'data-coord="top-left:(85,74); bottom-right:(1180,1615)" '
#                      '/></figure>\n'
#                      "<p id='119' data-category='paragraph' "
#                      "style='font-size:14px'>※ 기타 자세한 사항은 보험 계약 체결 전, 상품설명서 및 "
#                      '약관을 반드시 읽어보시기 바랍니다.</p>\n'
#                      "<br><footer id='120' style='font-size:14px'>11</footer>\n"
#                      "<h1 id='121' style='font-size:14px'>메트라이프생명 무배당 아이사랑 "
#                      '첫보험</h1>\n'
#                      "<p id='122' data-category='paragraph' "
#                      "style='font-size:14px'>메트라이프생명 모바일 홈페이지에 접속해보세요.<br>회사 및 "
#                      '상품소개와 편리한 MetLife One(온라인창구)<br>활용방법을 확인하실 수 있습니다.</p>\n'
#                      "<p id='123' data-category='paragraph' "
#                      "style='font-size:14px'>메트라이프생명보험(주)<br>서울특별시 강남구 테헤란로 "
#                      '316 (역삼2동 메트라이프타워)<br>콜센터 : 1588-9600 '
#                      'www.metlife.co.kr</p>\n'
#                      "<p id='124' data-category='paragraph' "
#                      "style='font-size:14px'>제작 : 마케팅커뮤니케이션팀 "
#                      '(준법감시인확인필-6089-2403-546421,<br>유효기간-2024-03-29~2025-03-28)<br>인쇄코드 '
#                      ': 01-01-01364 인쇄일자 : 2024. 04. 01<br>© 2024 메트라이프생명보험(주) '
#                      'All rights reserved.</p>\n'
#                      "<br><p id='125' data-category='paragraph' "
#                      "style='font-size:14px'>12</p>",
#              'markdown': '# 무배당 아이사랑 첫보험\n'
#                          '\n'
#                          '※ 본 상품은 보장성상품이며, 저축(연금)목적에는 적합하지 않습니다.\n'
#                          '\n'
#                          '\n'
#                          '\n'
#                          '※ 기타 자세한 사항은 보험 계약 체결 전, 상품설명서 및 약관을 반드시 읽어보시기\n'
#                          '\n'
#                          '바랍니다. 1\n'
#                          '\n'
#                          '메트라이프생명 무배당 아이사랑 첫보험\n'
#                          '\n'
#                          '# 상품특징\n'
#                          '\n'
#                          '태아와 산모 모두 보호해주니까 안심(해당 특약 가입시)\n'
#                          '\n'
#                          '- Ÿ (무)주요선천이상진단특약\n'
#                          '- Ÿ (무)주산기수술특약\n'
#                          '\n'
#                          '\n'
#                          '- Ÿ (무)산모보장특약\n'
#                          '- Ÿ (무)저체중아보장특약\n'
#                          '- Ÿ (무)주산기입원특약\n'
#                          '\n'
#                          '\n'
#                          '# 큰 병도 보장해주니까 든든\n'
#                          '\n'
#                          '- Ÿ 어린이 고액암 진단비 Ÿ CI 치료자금\n'
#                          '- Ÿ 중대한 수술비\n'
#                          '\n'
#                          '\n'
#                          '# 질병 및 사고를 다양하게 보장\n'
#                          '\n'
#                          '- Ÿ 암 진단비 Ÿ 질병 및 재해 수술비 / 입원비\n'
#                          '- Ÿ 어린이 중요질환 수술비 / 입원비 Ÿ 어린이 생활질환 수술비 / 입원비\n'
#                          '- Ÿ 어린이 소액암진단비\n'
#                          '\n'
#                          '\n'
#                          '# 고객 니즈에 따라 맞춤 선택 가능\n'
#                          '\n'
#                          '- Ÿ 1종 : 순수보장형\n'
#                          '- Ÿ 2종 : 50% 만기환급형\n'
#                          '\n'
#                          '\n'
#                          '만일의 경우 아이의 미래를 위한 학자금으로 활용\n'
#                          '(해당 특약 가입시)\n'
#                          '\n'
#                          'Ÿ (무)보호자정기특약\n'
#                          '\n'
#                          '라이프사이클에 맞추어 다양한 헬스케어서비스 및\n'
#                          '종합 은퇴 관리 서비스 제공\n'
#                          '\n'
#                          '\n'
#                          '\n'
#                          '전문의료진 상담, 진료예약 및 명의안내는 물론, 가입금액에 따라 가족확대서비스와\n'
#                          '같은 다양한 헬스케어서비스를 제공합니다. 또한 간병인 제공, 시니어를 위한\n'
#                          '개인비서, 반려동물 헬스케어 등 든든하고 행복한 노후를 위한 차별화된 서비스를\n'
#                          '제공합니다.\n'
#                          '\n'
#                          '- ※ 헬스케어서비스는 보장성 상품 및 (무)변액연금보험 동행의 사망보장형 주계약 가입금액 '
#                          '합산액이\n'
#                          '- 5천만원 이상인 피보험자에게 제공됩니다.\n'
#                          '- ※ 만 15세 이후에 (무)아이사랑첫보험 유지 시 타 상품의 주계약 금액과 합산되어 '
#                          '헬스케어서비스가\n'
#                          '- 제공될 수 있습니다.\n'
#                          '- ※ 종합 은퇴 관리서비스(360Future)는 메트라이프생명 계약자 및 피보험자에게 '
#                          '제공합니다.\n'
#                          '- 다만 360Future 프리미엄서비스는 회사에서 정한 보장성상품 주계약 합산 1억원 이상\n'
#                          '- 저축성상품 월납 보험료 합산 100만원 이상 가입계약의 주피보험자에게 제공합니다.\n'
#                          '- ※ 자세한 서비스 내용은 메트라이프생명 홈페이지 및 MetLife One 앱을 참고하시기 '
#                          '바랍니다.\n'
#                          '- ※ 본 서비스는 서비스 개선 및 대내외 환경 변화로 인해 향후 서비스 내용이 축소되거나 '
#                          '변경 될 수\n'
#                          '- 있습니다.\n'
#                          '\n'
#                          '\n'
#                          '2\n'
#                          '\n'
#                          '# 보장내용\n'
#                          '\n'
#                          '예시기준 : 주계약 가입금액 1,000만원\n'
#                          '\n'
#                          '| 구분 | 지급사유 | 지급금액 |\n'
#                          '| --- | --- | --- |\n'
#                          '| 만기환급금 | 보험기간이 끝날 때까지 살아있을 때 (2종 50% 만기환급형만 해당) | '
#                          '이미 납입한 보혐료의 50% |\n'
#                          '| 암진단보험금 | 암 진단이 확정되었을 때 (최초 1회에 한함) | 2,000만원 |\n'
#                          '| 암진단보험금 | 갑상선암, 기타피부암, 제자리암, 경계성종양 진단이 확정되었을 때 (각각 '
#                          '최초 1회에 한함) | 200만원 |\n'
#                          '| CI치료자금 | 말기신부전증으로 진단이 확정되었을 때 (최초 1회에 한함) | '
#                          '2,000만원 |\n'
#                          '| CI치료자금 | 5대장기이식 수술을 받았을 때 (최초 1회에 한함) | 3,000만원 |\n'
#                          '| CI치료자금 | 중증 재생불량성빈혈 진단이 확정되었을 때 (최초 1회에 한함) | '
#                          '1,000만원 |\n'
#                          '| CI치료자금 | 양성뇌종양으로 진단이 확정되었을 때 (최초 1회에 한함) | 500만원 '
#                          '|\n'
#                          '| CI치료자금 | 중대한 화상 및 부식으로 진단이 확정되었을 때 (최초 1회에 한함) | '
#                          '3,000만원 |\n'
#                          '| 중대한 수술보험금 | 조혈모세포이식 수술을 받았을 때 (최초 1회에 한함) | '
#                          '2,000만원 |\n'
#                          '| 중대한 수술보험금 | 중대한 재해로 인한 수술을 받았을 때 (수술 1회당) | 300만원 '
#                          '|\n'
#                          '| 어린이질환수술보험금 | 어린이 중요질환으로 인한 수술을 받았을 때 (수술 1회당) | '
#                          '200만원 |\n'
#                          '| 어린이질환수술보험금 | 어린이 생활질환으로 인한 수술을 받았을 때 (수술 1회당) | '
#                          '50만원 |\n'
#                          '| 화상수술보험금 | 화상으로 인한 수술을 받았을 때 (수술 1회당) | 50만원 |\n'
#                          '| 질병 및 재해수술보험금 | 1~5종 수술분류표에서 정한 수술을 받았을 때 (수술 1회당) '
#                          '| 1종 : 10만원, 2종 : 30만원, 3종 : 50만원, 4종 : 100만원, 5종 : '
#                          '300만원 |\n'
#                          '| 어린이질환입원보험금 | 어린이 중요질환으로 입원하였을 때 3일 초과 1일당 (120일 '
#                          '한도) | 4만원 |\n'
#                          '| 어린이질환입원보험금 | 어린이 생활질환으로 입원하였을 때 3일 초과 1일당 (120일 '
#                          '한도) | 5천원 |\n'
#                          '| 컴퓨터-미디어 관련질환입원보험금 | 컴퓨터-미디어 관련질환으로 입원하였을 때 3일 초과 '
#                          '1일당 (120일 한도) | 1만원 |\n'
#                          '| 질병 및 재해입원보험금 | 질병 또는 재해로 인해 입원하였을 때 3일 초과 1일당 '
#                          '(120일 한도) | 2만원 |\n'
#                          '| 주요 법정감염병치료비 | 주요법정감염병으로 해당 보건소에 신고되어 감염병 환자로 진단이 '
#                          '확정되었을 때 (발생 1회당) | 50만원 |\n'
#                          '| 깁스치료비 | 질병 또는 재해로 깁스치료를 받았을 때 (발생 1회당) | 10만원 |\n'
#                          '| 재해골절치료비 | 재해로 인한 골절(치아파절 제외) 상태가 되었을 때 (발생 1회당) | '
#                          '30만원 |\n'
#                          '| 유괴납치 위로금 | 유괴·납치의 피해자가 되었을 때 (최초 1회에 한하며, 30세 '
#                          '계약해당일 전일까지만 보장) | 500만원 |\n'
#                          '| 재해장해보험금 | 교통재해로 장해상태가 되었을 때 | 1억원 × 해당장해지급률 |\n'
#                          '| 재해장해보험금 | 교통재해 이외의 재해로 장해상태가 되었을 때 | 5,000만원 × '
#                          '해당장해지급률 |\n'
#                          '\n'
#                          '\n'
#                          'Ÿ 보험료 납입면제 「암(갑상선암, 기타피부암, 제자리암 또는 경계성종양 제외)으로 진단 '
#                          '확정되었을 때」, 「말기신부전증으로 진단\n'
#                          '확정되었을 때」 또는 「장해분류표 중 동일한 재해 또는 재해 이외의 동일한 원인으로 여러 '
#                          '신체부위의 장해지급률을 더하여\n'
#                          '50%이상의 장해상태가 되었을 경우」에는 차회 이후의 보험료 납입이 면제됩니다. 단, '
#                          '태아보장기간에는 보험료 납입이 면제되지\n'
#                          '않습니다.\n'
#                          'Ÿ 피보험자가 사망한 경우에는 사망 당시의 계약자적립액을 지급하여 드리고 이 계약은 더 이상 '
#                          '효력을 가지지 아니합니다.\n'
#                          '단, 피보험자가 만 15세 미만 사망 시 이미 납입한 보험료와 계약자적립액 중 큰 금액을 '
#                          '지급합니다.\n'
#                          '\n'
#                          '※ 기타 자세한 사항은 보험 계약 체결 전, 상품설명서 및 약관을 반드시 읽어보시기 '
#                          '바랍니다.\n'
#                          '\n'
#                          '3\n'
#                          '\n'
#                          '메트라이프생명 무배당 아이사랑 첫보험\n'
#                          '\n'
#                          '# 가입안내\n'
#                          '\n'
#                          '| 상품유형 | 1종 : 순수보장형 | 1종 : 순수보장형 | 2종 : 50% 만기환급형 | '
#                          '2종 : 50% 만기환급형 |\n'
#                          '| --- | --- | --- | --- | --- |\n'
#                          '| 상품유형 | 태아형 | 어린이형 | 태아형 | 어린이형 |\n'
#                          '| 보험기간 | 30세 만기, 40세 만기 | 30세 만기, 40세 만기 | 40세 만기 | '
#                          '40세 만기 |\n'
#                          '| 가입나이 | 태아~15세(납입기간에 따라 다름) | 태아~15세(납입기간에 따라 다름) | '
#                          '태아~15세(납입기간에 따라 다름) | 태아~15세(납입기간에 따라 다름) |\n'
#                          '| 납입기간 | 태아(1개월~10개월) : 전기납 10년납, 15년납, 20년납 | '
#                          '태아(1개월~10개월) : 전기납 10년납, 15년납, 20년납 | 태아(1개월~10개월) : '
#                          '전기납 10년납, 15년납, 20년납 | 태아(1개월~10개월) : 전기납 10년납, '
#                          '15년납, 20년납 |\n'
#                          '| 가입금액 | 최저 1,000만원 ~ 최고 2,000만원(100만원 단위) | 최저 '
#                          '1,000만원 ~ 최고 2,000만원(100만원 단위) | 최저 1,000만원 ~ 최고 '
#                          '2,000만원(100만원 단위) | 최저 1,000만원 ~ 최고 2,000만원(100만원 '
#                          '단위) |\n'
#                          '| 납입주기 | 월납 | 월납 | 월납 | 월납 |\n'
#                          '\n'
#                          '\n'
#                          '- Ÿ 가입나이 및 가입한도 등의 계약인수 관련 사항은 회사가 정한 기준에 따라 제한될 수 '
#                          '있습니다.\n'
#                          '- Ÿ 피보험자로 될 자가 태아인 경우 계약일부터 출생시점(출산 또는 분만과정에서 보험금 '
#                          '지급사유가 발생하는 경우 포함)까지의 기간을\n'
#                          '- 태아보장기간으로 하여 1개월 ~ 10개월의 보험기간 및 보험료납입기간을 추가로 '
#                          '부가합니다.\n'
#                          '\n'
#                          '\n'
#                          '태아형이란?\n'
#                          '(무)아이사랑첫보험은 태아를 피보험자로 할 수 있습니다. 태아보장기간은 계약일로부터\n'
#                          '출생시점(출산 또는 분만과정에서 보험금 지급사유가 발생하는 경우 포함)까지이고, 이때 '
#                          '보험료는\n'
#                          '남자 보험료를 적용합니다. 출생예정일이 도래한 경우, 차회 이후의 보험료는 보험나이 0세 '
#                          '기준으로\n'
#                          '변경하여 적용하며, 출생한 피보험자의 성별이 변경되거나 계약체결 시 출생예정일과 실제출생일이 '
#                          '다른\n'
#                          '경우에는 보험료 및 해약환급금 산출방법서에서 정한 방법에 따라 해당 보험료를 정산합니다.\n'
#                          '피보험자가 태아인 경우, 어린이형 보험기간은 출생시점부터 계약자가 선택한 기간을 말합니다.\n'
#                          '태아보장기간 이후에도 태아보장기간 중에 발생한 위험을 원인으로 보험금 지급사유가 발생하는 '
#                          '경우\n'
#                          '보험금을 지급합니다.\n'
#                          '\n'
#                          '4\n'
#                          '\n'
#                          '# 보험료 예시\n'
#                          '\n'
#                          '예시기준 : 주계약 가입금액 1,000만원, 전기납, 월납/ 단위 : 원\n'
#                          '\n'
#                          '| 가입나이 | 남자 | 여자 |\n'
#                          '| --- | --- | --- |\n'
#                          '| 가입나이 | 1종 순수보장형 2종 50% 만기환급형 | 1종 순수보장형 2종 50% '
#                          '만기환급형 |\n'
#                          '| 태아(1개월~10개월) | 8,600 | 8,600 |\n'
#                          '\n'
#                          '\n'
#                          '예시기준 : 주계약 가입금액 1,000만원, 40세 만기, 월납/ 단위 : 원\n'
#                          '\n'
#                          '| 가입나이 | 남자 | 남자 | 남자 | 남자 | 여자 | 여자 | 여자 | 여자 |\n'
#                          '| --- | --- | --- | --- | --- | --- | --- | --- | '
#                          '--- |\n'
#                          '| 가입나이 | 1종 순수보장형 | 1종 순수보장형 | 2종 50% 만기환급형 | 2종 50% '
#                          '만기환급형 | 1종 순수보장형 | 1종 순수보장형 | 2종 50% 만기환급형 | 2종 50% '
#                          '만기환급형 |\n'
#                          '| 가입나이 | 10년납 | 20년납 | 10년납 | 20년납 | 10년납 | 20년납 | '
#                          '10년납 | 20년납 |\n'
#                          '| 0세 | 27,800 | 17,800 | 43,200 | 29,000 | 25,800 | '
#                          '16,600 | 40,000 | 27,200 |\n'
#                          '| 5세 | 26,100 | 16,800 | 43,400 | 29,800 | 24,300 | '
#                          '15,800 | 40,400 | 28,000 |\n'
#                          '| 10세 | 25,700 | 16,600 | 46,400 | 32,300 | 24,100 | '
#                          '15,700 | 43,700 | 30,700 |\n'
#                          '\n'
#                          '\n'
#                          '• 위의 보험료는 가입나이, 성별, 보험기간 및 납입기간 등에 따라 달라질 수 있습니다.\n'
#                          '\n'
#                          '# 해약환급금 예시\n'
#                          '\n'
#                          '예시기준 : 주계약 가입금액 1,000만원, 5세 남자, 40세 만기 / 단위 : 만원, 만원 '
#                          '미만 절사\n'
#                          '\n'
#                          '| 경과기간 | 1종 순수보장형 (20년납) | 1종 순수보장형 (20년납) | 1종 '
# ...
#                            'text': '기존계약 해지 후 신계약 체결시 불이익 사항'},
#                'coordinates': [{'x': 0.5221, 'y': 0.5502},
#                                {'x': 0.833, 'y': 0.5502},
#                                {'x': 0.833, 'y': 0.5646},
#                                {'x': 0.5221, 'y': 0.5646}],
#                'id': 108,
#                'page': 10},
#               {'category': 'paragraph',
#                'content': {'html': "<br><p id='109' data-category='paragraph' "
#                                    "style='font-size:14px'>보험계약자가 기존에 체결했던 "
#                                    '보험계약을 해지하고 다른<br>보험계약을 체결하면, 보험인수가 거절되거나 '
#                                    '보험료가 인상 또는<br>보장내용이 달라질 수 있습니다.</p>',
#                            'markdown': '보험계약자가 기존에 체결했던 보험계약을 해지하고 다른\n'
#                                        '보험계약을 체결하면, 보험인수가 거절되거나 보험료가 인상 또는\n'
#                                        '보장내용이 달라질 수 있습니다.',
#                            'text': '보험계약자가 기존에 체결했던 보험계약을 해지하고 다른\n'
#                                    '보험계약을 체결하면, 보험인수가 거절되거나 보험료가 인상 또는\n'
#                                    '보장내용이 달라질 수 있습니다.'},
#                'coordinates': [{'x': 0.5223, 'y': 0.5695},
#                                {'x': 0.8758, 'y': 0.5695},
#                                {'x': 0.8758, 'y': 0.606},
#                                {'x': 0.5223, 'y': 0.606}],
#                'id': 109,
#                'page': 10},
#               {'category': 'paragraph',
#                'content': {'html': "<p id='110' data-category='paragraph' "
#                                    "style='font-size:18px'>해약환급금이 납입보험료 보다 적은 "
#                                    '이유</p>',
#                            'markdown': '해약환급금이 납입보험료 보다 적은 이유',
#                            'text': '해약환급금이 납입보험료 보다 적은 이유'},
#                'coordinates': [{'x': 0.5222, 'y': 0.6186},
#                                {'x': 0.8012, 'y': 0.6186},
#                                {'x': 0.8012, 'y': 0.6333},
#                                {'x': 0.5222, 'y': 0.6333}],
#                'id': 110,
#                'page': 10},
#               {'category': 'paragraph',
#                'content': {'html': "<br><p id='111' data-category='paragraph' "
#                                    "style='font-size:14px'>계약자가 납입한 보험료는 불의의 "
#                                    '사고를 당한 다른 가입자에게<br>보험금으로 지급되고 보험회사 운영에 필요한 '
#                                    '경비로 사용되므로<br>중도 해지하는 경우 지급되는 해약환급금은 납입한 '
#                                    '보험료보다<br>적거나 없을 수 있습니다.</p>',
#                            'markdown': '계약자가 납입한 보험료는 불의의 사고를 당한 다른 가입자에게\n'
#                                        '보험금으로 지급되고 보험회사 운영에 필요한 경비로 사용되므로\n'
#                                        '중도 해지하는 경우 지급되는 해약환급금은 납입한 보험료보다\n'
#                                        '적거나 없을 수 있습니다.',
#                            'text': '계약자가 납입한 보험료는 불의의 사고를 당한 다른 가입자에게\n'
#                                    '보험금으로 지급되고 보험회사 운영에 필요한 경비로 사용되므로\n'
#                                    '중도 해지하는 경우 지급되는 해약환급금은 납입한 보험료보다\n'
#                                    '적거나 없을 수 있습니다.'},
#                'coordinates': [{'x': 0.5227, 'y': 0.638},
#                                {'x': 0.8739, 'y': 0.638},
#                                {'x': 0.8739, 'y': 0.6871},
#                                {'x': 0.5227, 'y': 0.6871}],
#                'id': 111,
#                'page': 10},
#               {'category': 'paragraph',
#                'content': {'html': "<p id='112' data-category='paragraph' "
#                                    "style='font-size:18px'>보험 분쟁 및 상담안내</p>",
#                            'markdown': '보험 분쟁 및 상담안내',
#                            'text': '보험 분쟁 및 상담안내'},
#                'coordinates': [{'x': 0.5226, 'y': 0.6998},
#                                {'x': 0.6794, 'y': 0.6998},
#                                {'x': 0.6794, 'y': 0.7147},
#                                {'x': 0.5226, 'y': 0.7147}],
#                'id': 112,
#                'page': 10},
#               {'category': 'paragraph',
#                'content': {'html': "<br><p id='113' data-category='paragraph' "
#                                    "style='font-size:14px'>생명보험에 대해 궁금하시거나 "
#                                    '불만사항이 있는 경우<br>메트라이프생명 콜센터(1588-9600)로 '
#                                    '문의하시면 성실히 안내해<br>드리겠습니다. 또한, 당사 상담결과에 이의가 '
#                                    '있으시면 금융감독원<br>(국번없이 1332, www.fss.or.kr)에 '
#                                    '민원 또는 분쟁조정을<br>신청하실 수 있습니다.</p>',
#                            'markdown': '생명보험에 대해 궁금하시거나 불만사항이 있는 경우\n'
#                                        '메트라이프생명 콜센터(1588-9600)로 문의하시면 성실히 안내해\n'
#                                        '드리겠습니다. 또한, 당사 상담결과에 이의가 있으시면 금융감독원\n'
#                                        '(국번없이 1332, www.fss.or.kr)에 민원 또는 '
#                                        '분쟁조정을\n'
#                                        '신청하실 수 있습니다.',
#                            'text': '생명보험에 대해 궁금하시거나 불만사항이 있는 경우\n'
#                                    '메트라이프생명 콜센터(1588-9600)로 문의하시면 성실히 안내해\n'
#                                    '드리겠습니다. 또한, 당사 상담결과에 이의가 있으시면 금융감독원\n'
#                                    '(국번없이 1332, www.fss.or.kr)에 민원 또는 분쟁조정을\n'
#                                    '신청하실 수 있습니다.'},
#                'coordinates': [{'x': 0.5226, 'y': 0.7186},
#                                {'x': 0.8826, 'y': 0.7186},
#                                {'x': 0.8826, 'y': 0.7789},
#                                {'x': 0.5226, 'y': 0.7789}],
#                'id': 113,
#                'page': 10},
#               {'category': 'paragraph',
#                'content': {'html': "<p id='114' data-category='paragraph' "
#                                    "style='font-size:18px'>보험계약 관련 조회시스템 "
#                                    '운영</p>',
#                            'markdown': '보험계약 관련 조회시스템 운영',
#                            'text': '보험계약 관련 조회시스템 운영'},
#                'coordinates': [{'x': 0.5219, 'y': 0.793},
#                                {'x': 0.7375, 'y': 0.793},
#                                {'x': 0.7375, 'y': 0.8071},
#                                {'x': 0.5219, 'y': 0.8071}],
#                'id': 114,
#                'page': 10},
#               {'category': 'paragraph',
#                'content': {'html': "<br><p id='115' data-category='paragraph' "
#                                    "style='font-size:14px'>계약자께서는 본 상품에 대한 자세한 "
#                                    '내용과 본 상품으로<br>보험설계를 하실 경우 또는 당사의 상품과 유사한 '
#                                    '다른 회사의<br>상품을 비교하실 경우 아래 인터넷 사이트를 통해 확인하실 '
#                                    '수<br>있습니다.</p>',
#                            'markdown': '계약자께서는 본 상품에 대한 자세한 내용과 본 상품으로\n'
#                                        '보험설계를 하실 경우 또는 당사의 상품과 유사한 다른 회사의\n'
#                                        '상품을 비교하실 경우 아래 인터넷 사이트를 통해 확인하실 수\n'
#                                        '있습니다.',
#                            'text': '계약자께서는 본 상품에 대한 자세한 내용과 본 상품으로\n'
#                                    '보험설계를 하실 경우 또는 당사의 상품과 유사한 다른 회사의\n'
#                                    '상품을 비교하실 경우 아래 인터넷 사이트를 통해 확인하실 수\n'
#                                    '있습니다.'},
#                'coordinates': [{'x': 0.5208, 'y': 0.8121},
#                                {'x': 0.8684, 'y': 0.8121},
#                                {'x': 0.8684, 'y': 0.8604},
#                                {'x': 0.5208, 'y': 0.8604}],
#                'id': 115,
#                'page': 10},
#               {'category': 'paragraph',
#                'content': {'html': "<br><p id='116' data-category='paragraph' "
#                                    "style='font-size:14px'>• 보험상품 및 가격공시실 : "
#                                    'www.metlife.co.kr (당사 홈페이지)<br>• 보험상품 '
#                                    '비교·공시 : www.klia.or.kr (생명보험협회 홈페이지)</p>',
#                            'markdown': '• 보험상품 및 가격공시실 : www.metlife.co.kr (당사 '
#                                        '홈페이지)\n'
#                                        '• 보험상품 비교·공시 : www.klia.or.kr (생명보험협회 '
#                                        '홈페이지)',
#                            'text': '• 보험상품 및 가격공시실 : www.metlife.co.kr (당사 '
#                                    '홈페이지)\n'
#                                    '• 보험상품 비교·공시 : www.klia.or.kr (생명보험협회 '
#                                    '홈페이지)'},
#                'coordinates': [{'x': 0.5213, 'y': 0.8606},
#                                {'x': 0.8818, 'y': 0.8606},
#                                {'x': 0.8818, 'y': 0.8867},
#                                {'x': 0.5213, 'y': 0.8867}],
#                'id': 116,
#                'page': 10},
#               {'category': 'footer',
#                'content': {'html': "<footer id='117' "
#                                    "style='font-size:16px'>10</footer>",
#                            'markdown': '10',
#                            'text': '10'},
#                'coordinates': [{'x': 0.0607, 'y': 0.9358},
#                                {'x': 0.0823, 'y': 0.9358},
#                                {'x': 0.0823, 'y': 0.9488},
#                                {'x': 0.0607, 'y': 0.9488}],
#                'id': 117,
#                'page': 10},
#               {'base64_encoding': '...',
#                'category': 'figure',
#                'content': {'html': '<figure><img id=\'118\' alt="" '
#                                    'data-coord="top-left:(85,74); '
#                                    'bottom-right:(1180,1615)" /></figure>',
#                            'markdown': '',
#                            'text': ''},
#                'coordinates': [{'x': 0.0692, 'y': 0.0424},
#                                {'x': 0.9519, 'y': 0.0424},
#                                {'x': 0.9519, 'y': 0.9213},
#                                {'x': 0.0692, 'y': 0.9213}],
#                'id': 118,
#                'page': 11},
#               {'category': 'paragraph',
#                'content': {'html': "<p id='119' data-category='paragraph' "
#                                    "style='font-size:14px'>※ 기타 자세한 사항은 보험 계약 "
#                                    '체결 전, 상품설명서 및 약관을 반드시 읽어보시기 바랍니다.</p>',
#                            'markdown': '※ 기타 자세한 사항은 보험 계약 체결 전, 상품설명서 및 약관을 '
#                                        '반드시 읽어보시기 바랍니다.',
#                            'text': '※ 기타 자세한 사항은 보험 계약 체결 전, 상품설명서 및 약관을 반드시 '
#                                    '읽어보시기 바랍니다.'},
#                'coordinates': [{'x': 0.309, 'y': 0.9342},
#                                {'x': 0.8942, 'y': 0.9342},
#                                {'x': 0.8942, 'y': 0.9508},
#                                {'x': 0.309, 'y': 0.9508}],
#                'id': 119,
#                'page': 11},
#               {'category': 'footer',
#                'content': {'html': "<br><footer id='120' "
#                                    "style='font-size:14px'>11</footer>",
#                            'markdown': '11',
#                            'text': '11'},
#                'coordinates': [{'x': 0.9185, 'y': 0.9352},
#                                {'x': 0.9407, 'y': 0.9352},
#                                {'x': 0.9407, 'y': 0.9492},
#                                {'x': 0.9185, 'y': 0.9492}],
#                'id': 120,
#                'page': 11},
#               {'category': 'heading1',
#                'content': {'html': "<h1 id='121' "
#                                    "style='font-size:14px'>메트라이프생명 무배당 아이사랑 "
#                                    '첫보험</h1>',
#                            'markdown': '# 메트라이프생명 무배당 아이사랑 첫보험',
#                            'text': '메트라이프생명 무배당 아이사랑 첫보험'},
#                'coordinates': [{'x': 0.0604, 'y': 0.0344},
#                                {'x': 0.2929, 'y': 0.0344},
#                                {'x': 0.2929, 'y': 0.0472},
#                                {'x': 0.0604, 'y': 0.0472}],
#                'id': 121,
#                'page': 12},
#               {'category': 'paragraph',
#                'content': {'html': "<p id='122' data-category='paragraph' "
#                                    "style='font-size:14px'>메트라이프생명 모바일 홈페이지에 "
#                                    '접속해보세요.<br>회사 및 상품소개와 편리한 MetLife '
#                                    'One(온라인창구)<br>활용방법을 확인하실 수 있습니다.</p>',
#                            'markdown': '메트라이프생명 모바일 홈페이지에 접속해보세요.\n'
#                                        '회사 및 상품소개와 편리한 MetLife One(온라인창구)\n'
#                                        '활용방법을 확인하실 수 있습니다.',
#                            'text': '메트라이프생명 모바일 홈페이지에 접속해보세요.\n'
#                                    '회사 및 상품소개와 편리한 MetLife One(온라인창구)\n'
#                                    '활용방법을 확인하실 수 있습니다.'},
#                'coordinates': [{'x': 0.1747, 'y': 0.0664},
#                                {'x': 0.51, 'y': 0.0664},
#                                {'x': 0.51, 'y': 0.1098},
#                                {'x': 0.1747, 'y': 0.1098}],
#                'id': 122,
#                'page': 12},
#               {'category': 'paragraph',
#                'content': {'html': "<p id='123' data-category='paragraph' "
#                                    "style='font-size:14px'>메트라이프생명보험(주)<br>서울특별시 "
#                                    '강남구 테헤란로 316 (역삼2동 메트라이프타워)<br>콜센터 : '
#                                    '1588-9600 www.metlife.co.kr</p>',
#                            'markdown': '메트라이프생명보험(주)\n'
#                                        '서울특별시 강남구 테헤란로 316 (역삼2동 메트라이프타워)\n'
#                                        '콜센터 : 1588-9600 www.metlife.co.kr',
#                            'text': '메트라이프생명보험(주)\n'
#                                    '서울특별시 강남구 테헤란로 316 (역삼2동 메트라이프타워)\n'
#                                    '콜센터 : 1588-9600 www.metlife.co.kr'},
#                'coordinates': [{'x': 0.0709, 'y': 0.8388},
#                                {'x': 0.4433, 'y': 0.8388},
#                                {'x': 0.4433, 'y': 0.8838},
#                                {'x': 0.0709, 'y': 0.8838}],
#                'id': 123,
#                'page': 12},
#               {'category': 'paragraph',
#                'content': {'html': "<p id='124' data-category='paragraph' "
#                                    "style='font-size:14px'>제작 : 마케팅커뮤니케이션팀 "
#                                    '(준법감시인확인필-6089-2403-546421,<br>유효기간-2024-03-29~2025-03-28)<br>인쇄코드 '
#                                    ': 01-01-01364 인쇄일자 : 2024. 04. 01<br>© '
#                                    '2024 메트라이프생명보험(주) All rights reserved.</p>',
#                            'markdown': '제작 : 마케팅커뮤니케이션팀 '
#                                        '(준법감시인확인필-6089-2403-546421,\n'
#                                        '유효기간-2024-03-29~2025-03-28)\n'
#                                        '인쇄코드 : 01-01-01364 인쇄일자 : 2024. 04. '
#                                        '01\n'
#                                        '© 2024 메트라이프생명보험(주) All rights '
#                                        'reserved.',
#                            'text': '제작 : 마케팅커뮤니케이션팀 '
#                                    '(준법감시인확인필-6089-2403-546421,\n'
#                                    '유효기간-2024-03-29~2025-03-28)\n'
#                                    '인쇄코드 : 01-01-01364 인쇄일자 : 2024. 04. 01\n'
#                                    '© 2024 메트라이프생명보험(주) All rights reserved.'},
#                'coordinates': [{'x': 0.0722, 'y': 0.9003},
#                                {'x': 0.5158, 'y': 0.9003},
#                                {'x': 0.5158, 'y': 0.9523},
#                                {'x': 0.0722, 'y': 0.9523}],
#                'id': 124,
#                'page': 12},
#               {'category': 'paragraph',
#                'content': {'html': "<br><p id='125' data-category='paragraph' "
#                                    "style='font-size:14px'>12</p>",
#                            'markdown': '12',
#                            'text': '12'},
#                'coordinates': [{'x': 0.0604, 'y': 0.9368},
#                                {'x': 0.0804, 'y': 0.9368},
#                                {'x': 0.0804, 'y': 0.9496},
#                                {'x': 0.0604, 'y': 0.9496}],
#                'id': 125,
#                'page': 12}],
#  'model': 'document-parse-240910',
#  'usage': {'pages': 12}}
